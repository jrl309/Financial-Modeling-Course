# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib as plt
from matplotlib import pyplot as plt 
import statsmodels.api as sm
from scipy.stats import pearsonr

brazil_data = yf.download("USDBRL=X", start = "2013-11-25" , end = "2022-07-15")
brazil_data["Moves_BRL"] = brazil_data["Adj Close"] / brazil_data["Adj Close"].shift(1) 
print("BRL DATA") 
print(brazil_data)
australia_data = yf.download("AUDUSD=X", start = "2013-11-25" , end = "2022-07-15")
australia_data["Moves_AUD"] = australia_data["Adj Close"] / australia_data["Adj Close"].shift(1)
print("AUD DATA") 
print(australia_data)

plt.plot(brazil_data["Moves_BRL"].cumprod())
plt.plot(australia_data["Moves_AUD"].cumprod(), color = "red")
plt.title("USD/BRL & AUD/USD")
plt.xlabel("Year")
plt.ylabel("Value")
plt.legend(["USD/BRL", "AUD/USD"])
Xdata = brazil_data["Moves_BRL"]
Ydata = australia_data["Moves_AUD"]
Xdata = (sm.add_constant(Xdata))

regresults = sm.OLS(Ydata, Xdata, missing = "drop").fit()
print(regresults.summary())
# Out:
# [*********************100%***********************]  1 of 1 completed
# BRL DATA
#               Open    High       Low   Close  Adj Close  Volume  Moves_BRL
# Date
# 2013-11-25  2.2758  2.2926  2.262000  2.2738     2.2738       0        NaN
# 2013-11-26  2.2819  2.3030  2.278800  2.2808     2.2808       0   1.003079
# 2013-11-27  2.2896  2.3110  2.289600  2.2938     2.2938       0   1.005700
# 2013-11-28  2.3270  2.3373  2.309800  2.3270     2.3270       0   1.014474
# 2013-11-29  2.3152  2.3368  2.300500  2.3149     2.3149       0   0.994800
# ...            ...     ...       ...     ...        ...     ...        ...
# 2022-07-11  5.2540  5.3590  5.250876  5.2540     5.2540       0   0.984227
# 2022-07-12  5.3772  5.4270  5.371500  5.3772     5.3772       0   1.023449
# 2022-07-13  5.4365  5.4625  5.362110  5.4365     5.4365       0   1.011028
# 2022-07-14  5.3909  5.4866  5.388757  5.3909     5.3909       0   0.991612
# 2022-07-15  5.4228  5.4461  5.375200  5.4228     5.4228       0   1.005917
#
# [2252 rows x 7 columns]
# [*********************100%***********************]  1 of 1 completed
# AUD DATA
#                 Open      High       Low     Close  Adj Close  Volume  \
# Date
# 2013-11-25  0.916674  0.918864  0.912159  0.916590   0.916590       0
# 2013-11-26  0.919287  0.920471  0.909008  0.919287   0.919287       0
# 2013-11-27  0.912076  0.913743  0.907112  0.912326   0.912326       0
# 2013-11-28  0.908513  0.914746  0.907935  0.908430   0.908430       0
# 2013-11-29  0.908100  0.913826  0.905715  0.908430   0.908430       0
# ...              ...       ...       ...       ...        ...     ...
# 2022-07-11  0.684580  0.684600  0.671790  0.684580   0.684580       0
# 2022-07-12  0.674332  0.677860  0.671249  0.674332   0.674332       0
# 2022-07-13  0.674700  0.680370  0.672830  0.674700   0.674700       0
# 2022-07-14  0.673230  0.678700  0.668320  0.673230   0.673230       0
# 2022-07-15  0.675489  0.680550  0.672030  0.675489   0.675489       0
#
#             Moves_AUD
# Date
# 2013-11-25        NaN
# 2013-11-26   1.002942
# 2013-11-27   0.992428
# 2013-11-28   0.995730
# 2013-11-29   1.000000
# ...               ...
# 2022-07-11   0.999532
# 2022-07-12   0.985030
# 2022-07-13   1.000547
# 2022-07-14   0.997821
# 2022-07-15   1.003354
#
# [2252 rows x 7 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Moves_AUD   R-squared:                       0.115
# Model:                            OLS   Adj. R-squared:                  0.115
# Method:                 Least Squares   F-statistic:                     293.3
# Date:                Sat, 21 Jan 2023   Prob (F-statistic):           6.62e-62
# Time:                        14:27:44   Log-Likelihood:                 8409.9
# No. Observations:                2251   AIC:                        -1.682e+04
# Df Residuals:                    2249   BIC:                        -1.680e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.1876      0.011    108.357      0.000       1.166       1.209
# Moves_BRL     -0.1876      0.011    -17.127      0.000      -0.209      -0.166
# ==============================================================================
# Omnibus:                       92.490   Durbin-Watson:                   2.105
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              287.316
# Skew:                          -0.024   Prob(JB):                     4.07e-63
# Kurtosis:                       4.750   Cond. No.                         180.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib as plt
from matplotlib import pyplot as plt 
import statsmodels.api as sm

brazil_data = yf.download("USDBRL=X", start = "2013-11-25" , end = "2022-07-15")
canada_data = yf.download("USDCAD=X", start = "2013-11-25" , end = "2022-07-15")
brazil_data["Moves_BRL"] = brazil_data["Adj Close"] / brazil_data["Adj Close"].shift(1)
canada_data["Moves_CAD"] = canada_data["Adj Close"] / canada_data["Adj Close"].shift(1)
plt.plot(brazil_data["Moves_BRL"].cumprod())
plt.plot(canada_data["Moves_CAD"].cumprod(), color = "orange")
plt.title("USD/BRL & USD/CAD")
plt.xlabel("Year")
plt.ylabel("Value")
plt.legend(["USD/BRL", "USD/CAD"])

Ydata = brazil_data["Moves_BRL"]
Xdata = canada_data["Moves_CAD"]
Xdata = (sm.add_constant(Xdata))
regresults = sm.OLS(Ydata, Xdata, missing = "drop").fit()
print(regresults.summary())
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Moves_BRL   R-squared:                       0.102
# Model:                            OLS   Adj. R-squared:                  0.101
# Method:                 Least Squares   F-statistic:                     254.6
# Date:                Sat, 21 Jan 2023   Prob (F-statistic):           2.25e-54
# Time:                        14:29:33   Log-Likelihood:                 7056.4
# No. Observations:                2251   AIC:                        -1.411e+04
# Df Residuals:                    2249   BIC:                        -1.410e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2461      0.047      5.204      0.000       0.153       0.339
# Moves_CAD      0.7543      0.047     15.955      0.000       0.662       0.847
# ==============================================================================
# Omnibus:                      261.083   Durbin-Watson:                   2.307
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1618.522
# Skew:                           0.354   Prob(JB):                         0.00
# Kurtosis:                       7.093   Cond. No.                         426.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib as plt
from matplotlib import pyplot as plt 
import statsmodels.api as sm

brazil_data = yf.download("USDBRL=X", start = "2013-11-25" , end = "2022-07-15")
nokkie_data = yf.download("NOK=X", start = "2013-11-25" , end = "2022-07-15")
brazil_data["Moves_BRL"] = brazil_data["Adj Close"] / brazil_data["Adj Close"].shift(1)
nokkie_data["Moves_NOK"] = nokkie_data["Adj Close"] / nokkie_data["Adj Close"].shift(1)
plt.plot(brazil_data["Moves_BRL"].cumprod())
plt.plot(nokkie_data["Moves_NOK"].cumprod(), color = "g")
plt.title("USD/BRL & USD/NOK")
plt.xlabel("Year")
plt.ylabel("Value")
plt.legend(["USD/BRL", "USD/NOK"])
Ydata = brazil_data["Moves_BRL"]
Xdata = nokkie_data["Moves_NOK"]
Xdata = (sm.add_constant(Xdata))
regresults = sm.OLS(Ydata, Xdata, missing = "drop").fit()
print(regresults.summary())
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Moves_BRL   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     34.51
# Date:                Sat, 21 Jan 2023   Prob (F-statistic):           4.86e-09
# Time:                        14:32:24   Log-Likelihood:                 6952.8
# No. Observations:                2251   AIC:                        -1.390e+04
# Df Residuals:                    2249   BIC:                        -1.389e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9100      0.015     59.091      0.000       0.880       0.940
# Moves_NOK      0.0904      0.015      5.875      0.000       0.060       0.121
# ==============================================================================
# Omnibus:                      222.294   Durbin-Watson:                   2.274
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1404.928
# Skew:                           0.215   Prob(JB):                    8.39e-306
# Kurtosis:                       6.846   Cond. No.                         132.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib as plt
from matplotlib import pyplot as plt 
import statsmodels.api as sm
brazil_data = yf.download("USDBRL=X", start = "2013-11-25" , end ="2022-07-15", )

brazil_data["Moves_BRL"] = brazil_data["Adj Close"] / brazil_data["Adj Close"].shift(1)

wti_data = yf.download("CL=F", start = "2013-11-25" , end = "2022-07-15") 
wti_data["Moves_WTI"] = wti_data["Adj Close"] / wti_data["Adj Close"].shift(1) 

plt.plot(brazil_data["Moves_BRL"].cumprod())
plt.plot(wti_data["Moves_WTI"].cumprod())
plt.title("USD/BRL & USD/WTI")
plt.xlabel("Year")
plt.ylabel("Value")
plt.legend(["USD/BRL", "USD/WTI"])


Ydata = brazil_data["Moves_BRL"].head(2173)
Xdata = wti_data["Moves_WTI"]
Xdata = (sm.add_constant(Xdata))
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
